# %% [markdown]
# Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
  accuracy_score, precision_score, recall_score, f1_score,
  classification_report, confusion_matrix, ConfusionMatrixDisplay
)

# %% [markdown]
# Load dataset

# %%
df = pd.read_csv('dataset/Earthquake.csv')
print('(rows, cols) :', df.shape)
df.head()
# Out:
# (rows, cols) : (17100, 22)
#                        time  latitude  ...  locationSource  magSource
# 0  2026-05-30T21:15:59.807Z   38.3564  ...              us         us
# 1  2026-05-29T12:22:54.128Z   23.4621  ...              us         us
# 2  2026-05-28T02:37:50.460Z   33.1393  ...              us         us
# 3  2026-05-26T16:30:57.714Z   23.1849  ...              us         us
# 4  2026-05-26T14:07:51.354Z   23.7982  ...              us         us
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17100 entries, 0 to 17099
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             17100 non-null  str
#  1   latitude         17100 non-null  float64
#  2   longitude        17100 non-null  float64
#  3   depth            17100 non-null  float64
#  4   mag              17100 non-null  float64
#  5   magType          17100 non-null  str
#  6   nst              7219 non-null   float64
#  7   gap              10442 non-null  float64
#  8   dmin             6236 non-null   float64
#  9   rms              16844 non-null  float64
#  10  net              17100 non-null  str
#  11  id               17100 non-null  str
#  12  updated          17100 non-null  str
#  13  place            17100 non-null  str
#  14  type             17100 non-null  str
#  15  horizontalError  5752 non-null   float64
#  16  depthError       10195 non-null  float64
#  17  magError         6199 non-null   float64
#  18  magNst           15512 non-null  float64
#  19  status           17100 non-null  str
#  20  locationSource   17100 non-null  str
#  21  magSource        17100 non-null  str
# dtypes: float64(12), str(10)
# memory usage: 2.9 MB
